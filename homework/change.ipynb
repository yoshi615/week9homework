# %%
# !pip install geopandas

import geopandas as gpd
import pandas as pd

# GeoJSON 読み込み
gdf = gpd.read_file("mie_mesh.geojson")

# 統計データ（txt）読み込み
df = pd.read_csv("tblT001100S5136.txt", encoding="shift-jis", skiprows=[1])
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: geopandas in c:\users\yoshi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in c:\users\yoshi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\yoshi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in c:\users\yoshi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from geopandas) (23.2)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\yoshi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from geopandas) (2.2.3)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\yoshi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\yoshi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from geopandas) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yoshi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yoshi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas>=1.4.0->geopandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yoshi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas>=1.4.0->geopandas) (2024.2)
# Requirement already satisfied: certifi in c:\users\yoshi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyogrio>=0.7.2->geopandas) (2024.8.30)
# Requirement already satisfied: six>=1.5 in c:\users\yoshi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\yoshi\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Convert 'KEY_CODE' column to integer type in both dataframes
gdf['KEY_CODE'] = gdf['KEY_CODE'].astype(int)
df['KEY_CODE'] = df['KEY_CODE'].astype(int)

# Join on KEY_CODE
merged = gdf.merge(df, on="KEY_CODE", how="left")

# %%
import matplotlib.pyplot as plt

# Make the plot larger
fig, ax = plt.subplots(1, 1, figsize=(15, 10))

# Create a choropleth map
merged.plot(column='T001100001', ax=ax, legend=True,
            legend_kwds={'label': "Total Population",
                         'orientation': "horizontal"})

# Add a title (optional)
ax.set_title('Choropleth Map of Total Population')

# Display the plot
plt.show()

# %%
from IPython.display import FileLink

merged.to_file("mie_population.geojson", driver="GeoJSON")
FileLink("mie_population.geojson")
# Out:
# c:\Users\yoshi\OneDrive\デスクトップ\GIShomework9\week9homework\myself\mie_population.geojson
